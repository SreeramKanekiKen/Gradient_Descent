# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
def gradient_descent(x,y):
    m_curr=b_curr=0
    iterations=5
    n=len(x)
    learning_rate=0.2
    plt.scatter(x,y,color="red",marker="x")
    for i in range(iterations):
        y_predicted=m_curr*x+b_curr
        plt.plot(x,y_predicted,color="green")
        cost=(1/n)*sum([val**2 for val in (y-y_predicted)])
        md=-(2/n)*sum(x*(y-y_predicted))
        bd=-(2/n)*sum(y-y_predicted)
        m_curr=m_curr-learning_rate*md
        b_curr=b_curr-learning_rate*bd
        print("m {}, b{}, cost{} iteration{}".format(m_curr,b_curr,cost,i))

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m 12.4, b3.6, cost89.0 iteration0
# m -34.080000000000005, b-9.120000000000001, cost1227.56 iteration1
# m 139.21600000000007, b39.024000000000015, cost17090.062400000006 iteration2
# m -507.76320000000027, b-140.04480000000012, cost238066.68089600024 iteration3
# m 1906.848640000001, b528.8889600000002, cost3316419.385571843 iteration4
